# %%
mydata = read.csv("C:/Users/e122566/Documents/Product Management/Analytics/Data Governance/parseXML.csv", header=FALSE)

# %%
colnames(mydata) <- c("EventID", "FormID", "RegOptionID", "Count")
mydata
# Out:
#       EventID FormID RegOptionID Count
# 1     9521    90011  33859       14
# 2     9521    90012  33859       13
# 3     9521    90089  33859       14
# 4     9521    90090  33859       13
# 5     9521    90289  33859       14
# 6     9521    90290  33859       13
# 7     9521    90863  33859       17
# 8     9521    90863  38561       17
# 9     9521    90864  33859       13
# 10    9521    90864  38561       13
# 11    9521    90864  38609       13
# 12    9521    98707  33859       20
# 13    9521    98707  38561       20
# 14    9521    98707  38609       20
# 15    9521    98708  33859       13
# 16    9521    98708  38561       13
# 17    9521    98708  38609       13
# 18    9521    98753  33859       22
# 19    9521    98753  38561       22
# 20    9521    98753  38609       22
# 21    9521    98754  33859       13
# 22    9521    98754  38561       13
# 23    9521    98754  38609       13
# 24    9521    98754  38898       13
# 25    9521    99176  33859       29
# ...

# %%
install.packages('reshape', repos='http://cran.us.r-project.org')
# Out:
# also installing the dependency 'plyr'
# package 'plyr' successfully unpacked and MD5 sums checked
# package 'reshape' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\e122566\AppData\Local\Temp\RtmpaeiOeo\downloaded_packages

# %%
library(reshape)
# Out:
# Warning message:
# "package 'reshape' was built under R version 3.2.5"

# %%
cast(mydata, EventID ~ RegOptionID, max)
# Out:
# Using Count as value column.  Use the value argument to cast to override this choice
#     EventID 33859 38561 38609 38898 40103 42422 42724 42725 42726 ... 146039
# 1    9521     29    29    29    29  -Inf  -Inf  -Inf  -Inf  -Inf  ... -Inf
# 2   10831   -Inf  -Inf  -Inf  -Inf    15  -Inf  -Inf  -Inf  -Inf  ... -Inf
# 3   11166   -Inf  -Inf  -Inf  -Inf  -Inf    18  -Inf  -Inf  -Inf  ... -Inf
# 4   11251   -Inf  -Inf  -Inf  -Inf  -Inf  -Inf    14    14    14  ... -Inf
# 5   11457   -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  ... -Inf
# 6   11464   -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  ... -Inf
# 7   11567   -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  ... -Inf
# 8   11579   -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  ... -Inf
# 9   11598   -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  ... -Inf
# 10  11838   -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  -Inf  ... -Inf
# ...
